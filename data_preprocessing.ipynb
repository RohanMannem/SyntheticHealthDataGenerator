# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

# %%
# Load dataset - https://www.kaggle.com/datasets/prasad22/healthcare-dataset
df = pd.read_csv("healthcare_dataset.csv")

# %%
# Remove personally identifiable information
df = df.drop(['Name'], axis=1)

# %%
print(scaler.fit(df[['Age']]))
# Out:
# MinMaxScaler()

# %%
# Numerical Data that should be normalized to a 0-1 range to improve compatibility with LLMs
scaler = MinMaxScaler()
columns = ['Age', 'Billing Amount']
for c in columns:
    df[[c]] = scaler.fit_transform(df[[c]])
df
# Out:
#             Age  Gender Blood Type Medical Condition Date of Admission  \
# 0      0.223684    Male         B-            Cancer        2024-01-31
# 1      0.644737    Male         A+           Obesity        2019-08-20
# 2      0.828947  Female         A-           Obesity        2022-09-22
# 3      0.197368  Female         O+          Diabetes        2020-11-18
# 4      0.394737  Female        AB+            Cancer        2022-09-19
# ...         ...     ...        ...               ...               ...
# 55495  0.381579  Female         O+            Asthma        2020-08-16
# 55496  0.631579  Female        AB-           Obesity        2020-01-23
# 55497  0.328947  Female         B+      Hypertension        2020-07-13
# 55498  0.394737    Male         O-         Arthritis        2019-05-25
# 55499  0.526316  Female         O+         Arthritis        2024-04-02
#
#                  Doctor                      Hospital Insurance Provider  \
# 0         Matthew Smith               Sons and Miller         Blue Cross
# 1       Samantha Davies                       Kim Inc           Medicare
# 2      Tiffany Mitchell                      Cook PLC              Aetna
# 3           Kevin Wells    Hernandez Rogers and Vang,           Medicare
# 4        Kathleen Hanna                   White-White              Aetna
# ...                 ...                           ...                ...
# 55495     Joshua Jarvis                Jones-Thompson         Blue Cross
# 55496   Taylor Sullivan                  Tucker-Moyer              Cigna
# 55497    Joe Jacobs DVM  and Mahoney Johnson Vasquez,   UnitedHealthcare
# 55498    Kimberly Curry      Jackson Todd and Castro,           Medicare
# 55499     Dennis Warren                Henry Sons and              Aetna
#
#        Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0            0.380933          328         Urgent     2024-02-02  Paracetamol
# 1            0.650904          265      Emergency     2019-08-26    Ibuprofen
# 2            0.547053          205      Emergency     2022-10-07      Aspirin
# 3            0.728798          450       Elective     2020-12-18    Ibuprofen
# 4            0.296622          458         Urgent     2022-10-09   Penicillin
# ...               ...          ...            ...            ...          ...
# 55495        0.085064          417       Elective     2020-09-15   Penicillin
# 55496        0.611002          316       Elective     2020-02-01      Aspirin
# 55497        0.540949          347         Urgent     2020-08-10    Ibuprofen
# 55498        0.629137          321       Elective     2019-05-31    Ibuprofen
# 55499        0.109884          448         Urgent     2024-04-29    Ibuprofen
#
#        Test Results
# 0            Normal
# 1      Inconclusive
# 2            Normal
# 3          Abnormal
# 4          Abnormal
# ...             ...
# 55495      Abnormal
# 55496        Normal
# 55497      Abnormal
# 55498      Abnormal
# 55499      Abnormal
#
# [55500 rows x 14 columns]

# %%
# Categorical Data 
encoder = LabelEncoder()
columns = ['Gender', 'Blood Type', 'Medical Condition', 'Doctor', 'Hospital', 'Insurance Provider', 'Admission Type', 'Medication', 'Test Results']
for c in columns:
    print(c)
    hold_c = c
    c = c.replace(' ', '_').lower()
    c += '_encoded'
    print(c)
    df[c] = encoder.fit_transform(df[[hold_c]])
df
# Out:
# Gender
# gender_encoded
# Blood Type
# blood_type_encoded
# Medical Condition
# medical_condition_encoded
# Doctor
# doctor_encoded
# Hospital
# hospital_encoded
# Insurance Provider
# insurance_provider_encoded
# Admission Type
# admission_type_encoded
# Medication
# medication_encoded
# Test Results
# test_results_encoded
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/rmannem/Documents/SyntheticHealthDataGenerator/venv/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#             Age  Gender Blood Type Medical Condition Date of Admission  \
# 0      0.223684    Male         B-            Cancer        2024-01-31
# 1      0.644737    Male         A+           Obesity        2019-08-20
# 2      0.828947  Female         A-           Obesity        2022-09-22
# 3      0.197368  Female         O+          Diabetes        2020-11-18
# 4      0.394737  Female        AB+            Cancer        2022-09-19
# ...         ...     ...        ...               ...               ...
# 55495  0.381579  Female         O+            Asthma        2020-08-16
# 55496  0.631579  Female        AB-           Obesity        2020-01-23
# 55497  0.328947  Female         B+      Hypertension        2020-07-13
# 55498  0.394737    Male         O-         Arthritis        2019-05-25
# 55499  0.526316  Female         O+         Arthritis        2024-04-02
#
#                  Doctor                      Hospital Insurance Provider  \
# 0         Matthew Smith               Sons and Miller         Blue Cross
# 1       Samantha Davies                       Kim Inc           Medicare
# 2      Tiffany Mitchell                      Cook PLC              Aetna
# 3           Kevin Wells    Hernandez Rogers and Vang,           Medicare
# 4        Kathleen Hanna                   White-White              Aetna
# ...                 ...                           ...                ...
# 55495     Joshua Jarvis                Jones-Thompson         Blue Cross
# 55496   Taylor Sullivan                  Tucker-Moyer              Cigna
# 55497    Joe Jacobs DVM  and Mahoney Johnson Vasquez,   UnitedHealthcare
# 55498    Kimberly Curry      Jackson Todd and Castro,           Medicare
# 55499     Dennis Warren                Henry Sons and              Aetna
#
#        Billing Amount  Room Number  ...  Test Results gender_encoded  \
# 0            0.380933          328  ...        Normal              1
# 1            0.650904          265  ...  Inconclusive              1
# 2            0.547053          205  ...        Normal              0
# 3            0.728798          450  ...      Abnormal              0
# 4            0.296622          458  ...      Abnormal              0
# ...               ...          ...  ...           ...            ...
# 55495        0.085064          417  ...      Abnormal              0
# 55496        0.611002          316  ...        Normal              0
# 55497        0.540949          347  ...      Abnormal              0
# 55498        0.629137          321  ...      Abnormal              1
# 55499        0.109884          448  ...      Abnormal              0
#
#       blood_type_encoded medical_condition_encoded  doctor_encoded  \
# 0                      5                         2           26612
# 1                      0                         5           33648
# 2                      1                         5           37828
# 3                      6                         3           22511
# 4                      2                         2           21259
# ...                  ...                       ...             ...
# 55495                  6                         1           20003
# 55496                  3                         5           37149
# 55497                  4                         4           18550
# 55498                  7                         0           22665
# 55499                  6                         0           10782
#
#        hospital_encoded  insurance_provider_encoded  admission_type_encoded  \
# 0                 29933                           1                       2
# 1                 16012                           3                       1
# 2                  5473                           0                       1
# 3                 12317                           3                       0
# 4                 33598                           0                       2
# ...                 ...                         ...                     ...
# 55495             15553                           1                       0
# 55496             31722                           2                       0
# 55497             37408                           4                       2
# 55498             14329                           3                       0
# 55499             12207                           0                       2
#
#        medication_encoded  test_results_encoded
# 0                       3                     2
# 1                       1                     1
# 2                       0                     2
# 3                       1                     0
# 4                       4                     0
# ...                   ...                   ...
# 55495                   4                     0
# 55496                   0                     2
# 55497                   1                     0
# 55498                   1                     0
# 55499                   1                     0
#
# [55500 rows x 23 columns]
